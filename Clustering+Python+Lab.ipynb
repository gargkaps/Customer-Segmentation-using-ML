# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# **Overview**<br>
# <a href="https://archive.ics.uci.edu/ml/datasets/online+retail">Online retail is a transnational data set</a> which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# The steps are broadly:
# 1. Read and understand the data
# 2. Clean the data
# 3. Prepare the data for modelling
# 4. Modelling
# 5. Final analysis and reco

# %% [markdown]
# # 1. Read and visualise the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
# read the dataset
df = pd.read_csv("Online_Retail.csv", sep=",", encoding="ISO-8859-1", header=0)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
# basics of the df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # 2. Clean the data

# %%
# missing values
round(100*(df.isnull().sum())/len(df), 2)
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# CustomerID     24.93
# Country         0.00
# dtype: float64

# %%
# drop all rows having missing values
df = df.dropna()
df.shape
# Out:
# (406829, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
# new column: amount 
df['TotalPrice'] = df['Quantity']*df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom       15.30
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom       22.00
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# # 3. Prepare the data for modelling

# %% [markdown]
# - R (Recency): Number of days since last purchase
# - F (Frequency): Number of tracsactions
# - M (Monetary): Total amount of transactions (revenue contributed)

# %%
# monetary
df_1 = df.groupby('CustomerID')['TotalPrice'].sum()
df_1 = df_1.reset_index()
df_1.head()
# Out:
#    CustomerID  TotalPrice
# 0     12346.0        0.00
# 1     12347.0     4310.00
# 2     12348.0     1797.24
# 3     12349.0     1757.55
# 4     12350.0      334.40

# %%
# frequency
frequency = df.groupby('CustomerID')['InvoiceNo'].count()
frequency = frequency.reset_index()
frequency.columns = ['CustomerID', 'Frequency']
frequency.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
# merge the two dfs
grouped_df = pd.merge(df_1, frequency, on='CustomerID', how='inner')
grouped_df.head()
# Out:
#    CustomerID  TotalPrice  Frequency
# 0     12346.0        0.00          2
# 1     12347.0     4310.00        182
# 2     12348.0     1797.24         31
# 3     12349.0     1757.55         73
# 4     12350.0      334.40         17

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom       15.30
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom       22.00
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34

# %%
# recency
# convert to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], 
                                          format='%d-%m-%Y %H:%M')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
# compute the max date
max_date = max(df['InvoiceDate'])
max_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
# compute the diff
df['InvoiceDate'] = max_date - df['InvoiceDate']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 373 days 04:24:00       2.55     17850.0  United Kingdom       15.30
# 1 373 days 04:24:00       3.39     17850.0  United Kingdom       20.34
# 2 373 days 04:24:00       2.75     17850.0  United Kingdom       22.00
# 3 373 days 04:24:00       3.39     17850.0  United Kingdom       20.34
# 4 373 days 04:24:00       3.39     17850.0  United Kingdom       20.34

# %%
# recency
last_purchase = df.groupby('CustomerID')['InvoiceDate'].min()
last_purchase = last_purchase.reset_index()
last_purchase.head()
# Out:
#    CustomerID       InvoiceDate
# 0     12346.0 325 days 02:33:00
# 1     12347.0   1 days 20:58:00
# 2     12348.0  74 days 23:37:00
# 3     12349.0  18 days 02:59:00
# 4     12350.0 309 days 20:49:00

# %%
# merge
grouped_df = pd.merge(grouped_df, last_purchase, on='CustomerID', how='inner')
grouped_df.columns = ['CustomerID', 'amount', 'Frequency', 'recency']
grouped_df.head()
# Out:
#    CustomerID   amount  Frequency           recency
# 0     12346.0     0.00          2 325 days 02:33:00
# 1     12347.0  4310.00        182   1 days 20:58:00
# 2     12348.0  1797.24         31  74 days 23:37:00
# 3     12349.0  1757.55         73  18 days 02:59:00
# 4     12350.0   334.40         17 309 days 20:49:00

# %%
grouped_df.columns = ['CustomerID', 'Monetary', 'Frequency', 'Recency']
grouped_df.head()
# Out:
#    CustomerID  Monetary  Frequency           Recency
# 0     12346.0      0.00          2 325 days 02:33:00
# 1     12347.0   4310.00        182   1 days 20:58:00
# 2     12348.0   1797.24         31  74 days 23:37:00
# 3     12349.0   1757.55         73  18 days 02:59:00
# 4     12350.0    334.40         17 309 days 20:49:00

# %%
# number of days only
grouped_df['Recency'] = grouped_df['Recency'].dt.days
grouped_df.head()
# Out:
#    CustomerID  Monetary  Frequency  Recency
# 0     12346.0      0.00          2      325
# 1     12347.0   4310.00        182        1
# 2     12348.0   1797.24         31       74
# 3     12349.0   1757.55         73       18
# 4     12350.0    334.40         17      309

# %%
grouped_df[['CustomerID','Recency']].head()
# Out:
#    CustomerID  Recency
# 0     12346.0      325
# 1     12347.0        1
# 2     12348.0       74
# 3     12349.0       18
# 4     12350.0      309

# %%
grouped_df.columns=['CustomerID', 'amount', 'frequency', 'recency']
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency
# 0     12346.0     0.00          2      325
# 1     12347.0  4310.00        182        1
# 2     12348.0  1797.24         31       74
# 3     12349.0  1757.55         73       18
# 4     12350.0   334.40         17      309

# %%
# 1. outlier treatment
plt.boxplot(grouped_df['recency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x160329092b0>,
#   <matplotlib.lines.Line2D at 0x1603291f4c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1603291fcd0>,
#   <matplotlib.lines.Line2D at 0x1603291f910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16032909820>],
#  'medians': [<matplotlib.lines.Line2D at 0x1603291f0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16032910a30>],
#  'means': []}

# %%
# two types of outliers:
# - statistical
# - domain specific

# %%
# removing (statistical) outliers
Q1 = grouped_df.amount.quantile(0.05)
Q3 = grouped_df.amount.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_df[(grouped_df.amount >= Q1 - 1.5*IQR) & (grouped_df.amount <= Q3 + 1.5*IQR)]

# outlier treatment for recency
Q1 = grouped_df.recency.quantile(0.05)
Q3 = grouped_df.recency.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_df[(grouped_df.recency >= Q1 - 1.5*IQR) & (grouped_df.recency <= Q3 + 1.5*IQR)]

# outlier treatment for frequency
Q1 = grouped_df.frequency.quantile(0.05)
Q3 = grouped_df.frequency.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_df[(grouped_df.frequency >= Q1 - 1.5*IQR) & (grouped_df.frequency <= Q3 + 1.5*IQR)]

# %%
# 2. rescaling
rfm_df = grouped_df[['amount', 'frequency', 'recency']]

# instantiate
scaler = StandardScaler()

# fit_transform
rfm_df_scaled = scaler.fit_transform(rfm_df)
rfm_df_scaled.shape
# Out:
# (4293, 3)

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['TotalPrice', 'InvoiceNo', 'recency']
rfm_df_scaled.head()
# Out:
#    TotalPrice  InvoiceNo   recency
# 0   -0.723738  -0.752888  2.301611
# 1    1.731617   1.042467 -0.906466
# 2    0.300128  -0.463636 -0.183658
# 3    0.277517  -0.044720 -0.738141
# 4   -0.533235  -0.603275  2.143188

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
 
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
 
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H

# %%
#First convert the numpy array that you have to a dataframe
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['amount', 'frequency', 'recency']

# %%
#Use the Hopkins Statistic function by passing the above dataframe as a paramter
hopkins(rfm_df_scaled)
# Out:
# 0.9517156016510627

# %% [markdown]
# # 4. Modelling

# %%
# k-means with some arbitrary k
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([1, 2, 3, ..., 1, 3, 3])

# %%
# help(KMeans)

# %% [markdown]
# ## Finding the Optimal Number of Clusters
#
# ### SSD

# %%
# elbow-curve/SSD
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    ssd.append(kmeans.inertia_)
    
# plot the SSDs for each n_clusters
# ssd
plt.plot(ssd)

# %% [markdown]
# ### Silhouette Analysis
#
# $$\text{silhouette score}=\frac{p-q}{max(p,q)}$$
#
# $p$ is the mean distance to the points in the nearest cluster that the data point is not a part of
#
# $q$ is the mean intra-cluster distance to all the points in its own cluster.
#
# * The value of the silhouette score range lies between -1 to 1.
#
# * A score closer to 1 indicates that the data point is very similar to other data points in the cluster,
#
# * A score closer to -1 indicates that the data point is not similar to the data points in its cluster.

# %%
# silhouette analysis
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.5411246404292333
# For n_clusters=3, the silhouette score is 0.5084896296141937
# For n_clusters=4, the silhouette score is 0.477782010021685
# For n_clusters=5, the silhouette score is 0.4662700564189704
# For n_clusters=6, the silhouette score is 0.417731425549664
# For n_clusters=7, the silhouette score is 0.41768907282021733
# For n_clusters=8, the silhouette score is 0.4029113690382818

# %%
# final model with k=3
kmeans = KMeans(n_clusters=3, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
kmeans.labels_
# Out:
# array([0, 2, 1, ..., 0, 1, 1])

# %%
# assign the label
grouped_df['cluster_id'] = kmeans.labels_
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id
# 0     12346.0     0.00          2      325           0
# 1     12347.0  4310.00        182        1           2
# 2     12348.0  1797.24         31       74           1
# 3     12349.0  1757.55         73       18           1
# 4     12350.0   334.40         17      309           0

# %%
# plot
sns.boxplot(x='cluster_id', y='amount', data=grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='amount'>

# %% [markdown]
# ## Hierarchical Clustering

# %%
rfm_df_scaled.head()
# Out:
#      amount  frequency   recency
# 0 -0.723738  -0.752888  2.301611
# 1  1.731617   1.042467 -0.906466
# 2  0.300128  -0.463636 -0.183658
# 3  0.277517  -0.044720 -0.738141
# 4 -0.533235  -0.603275  2.143188

# %%
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id
# 0     12346.0     0.00          2      325           0
# 1     12347.0  4310.00        182        1           2
# 2     12348.0  1797.24         31       74           1
# 3     12349.0  1757.55         73       18           1
# 4     12350.0   334.40         17      309           0

# %%
# single linkage
mergings = linkage(rfm_df_scaled, method="single", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# complete linkage
mergings = linkage(rfm_df_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# 3 clusters
cluster_labels = cut_tree(mergings, n_clusters=3).reshape(-1, )
cluster_labels
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
# assign cluster labels
grouped_df['cluster_labels'] = cluster_labels
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id  cluster_labels
# 0     12346.0     0.00          2      325           0               0
# 1     12347.0  4310.00        182        1           2               1
# 2     12348.0  1797.24         31       74           1               0
# 3     12349.0  1757.55         73       18           1               0
# 4     12350.0   334.40         17      309           0               0

# %%
# plots
sns.boxplot(x='cluster_labels', y='recency', data=grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_labels', ylabel='recency'>

# %%
# plots
sns.boxplot(x='cluster_labels', y='frequency', data=grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_labels', ylabel='frequency'>

# %%
# plots
sns.boxplot(x='cluster_labels', y='amount', data=grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_labels', ylabel='amount'>
